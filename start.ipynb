# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from src.manager.lamainvest import Lamalyse
debug = True
analyser = Lamalyse()
analyser.debug = debug
# Out:
# ini class

# %%
df = pd.read_json(data[0])

# %%
df = pd.read_csv('src/data/data.csv')

# %%
df
# Out:
#     stockPriceFiveYearChange  stockPriceThreeYearChange  \
# 0                       0.00                       0.00
# 1                       0.00                       0.00
# 2                       3.67                       0.96
# 3                       0.37                       0.15
# 4                       1.48                       0.30
# ..                       ...                        ...
# 56                      0.62                       0.43
# 57                      0.67                       0.61
# 58                      0.47                       0.59
# 59                      0.85                       0.23
# 60                      0.43                       0.10
#
#     stockPriceOneYearChange buyRating earningsYearlyRating  \
# 0                      0.00         -                  ---
# 1                      0.00         +                  ---
# 2                     -0.02       ---                  +++
# 3                      0.16       ---                   ++
# 4                      0.01       ---                  +++
# ..                      ...       ...                  ...
# 56                     0.29       ---                  +++
# 57                     0.13       ---                  +++
# 58                     0.16       ---                  +++
# 59                    -0.09        --                  +++
# 60                     0.09       ---                  +++
#
#    earningsQuarterlyRating peRating dividendYieldRating payoutRatioRating  \
# 0                      ---      +++                   🙁                 😃
# 1                      ---      +++                   🙁                 😃
# 2                      ---      ---                   🙁                 😃
# 3                      ---       ++                   😃                 🙁
# 4                      +++        +                   🙁                 😃
# ..                     ...      ...                 ...               ...
# 56                     ---        +                   😃                 😃
# 57                     ---      ---                   😃                 🙁
# 58                     +++        +                   🙁                 🙁
# 59                     +++        +                   😃                 😃
# 60                      ++       ++                   😃                 🙁
#
#    returnOnEquityRating  ...     price  stockSymbol  \
# 0                     🙁  ...    26.790         UBER
# 1                     🙁  ...    43.040         LYFT
# 2                     😃  ...  1739.490         AMZN
# 3                     😃  ...    34.335       DPW.DE
# 4                     😃  ...   195.100           FB
# ..                  ...  ...       ...          ...
# 56                    😃  ...   145.750          HSY
# 57                    🙁  ...    85.350          WPC
# 58                    🙁  ...    41.180          OHI
# 59                    😃  ...    34.260         RAVN
# 60                    😃  ...   131.630          KMB
#
#                           shortName returnOnEquity  dividendYield  \
# 0           Uber Technologies, Inc.        0.00000         0.0000
# 1                        Lyft, Inc.        0.00000         0.0000
# 2                  Amazon.com, Inc.        0.23730         0.0000
# 3          DEUTSCHE POST AG NA O.N.        0.21445         0.0336
# 4                    Facebook, Inc.        0.20670         0.0000
# ..                              ...            ...            ...
# 56              The Hershey Company        0.84623         0.0211
# 57             W.P. Carey Inc. REIT        0.07268         0.0493
# 58  Omega Healthcare Investors, Inc        0.09040         0.0642
# 59           Raven Industries, Inc.        0.12310         0.0149
# 60       Kimberly-Clark Corporation       20.62000         0.0311
#
#     priceToEarnings  payoutRatio  yearlyRevenueTendency  \
# 0        -11.116183       0.0000                   1.48
# 1         -8.659960       0.0000                   3.12
# 2         63.811079       0.0000                   0.89
# 3         15.260000       0.6647                   0.04
# 4         21.275900       0.0000                   1.39
# ..              ...          ...                    ...
# 56        23.660714       0.4850                   0.05
# 57        45.641711       1.6462                   0.01
# 58        24.658683       1.6296                   0.19
# 59        23.958042       0.5000                   0.51
# 60        18.206086       0.7015                  -0.01
#
#     yearlyEarningsTendency  quarterlyEarningsTendency
# 0                    -1.00                      -1.00
# 1                    -1.00                      -1.00
# 2                     5.58                      -0.27
# 3                     0.51                      -0.24
# 4                     2.72                       0.76
# ..                     ...                        ...
# 56                    1.00                      -0.03
# 57                    1.07                      -1.06
# 58                    1.71                       1.07
# 59                    4.52                       2.37
# 60                    0.81                       0.56
#
# [61 rows x 21 columns]
